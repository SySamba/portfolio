# %% [markdown]
# Importation des librairies nécessaires

# %%
# Importation des librairies
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Chargement du dataset "Breast Cancer Wisconsin"
cancer_data = pd.read_csv('C:\\Users\\HP\\OneDrive\\Documents\\DeepLearning\\Breast-cancer-Wisconsin.csv')

# %%
# Aperçu des données sur le cancer du sein
print("\nBreast Cancer Wisconsin Data:")
print(cancer_data.head())
print(cancer_data.info())
print(cancer_data.describe())
# Out:
# Breast Cancer Wisconsin Data:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB
# None
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
# Vérification des valeurs manquantes dans le dataset Breast Cancer Wisconsin
print("Missing values in Breast Cancer Wisconsin Data:")
print(cancer_data.isnull().sum())
# Out:
# Missing values in Breast Cancer Wisconsin Data:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# Remplacement des étiquettes de la variable 'diagnosis' par des valeurs numériques (B = 0, M = 1)
cancer_data['diagnosis'] = cancer_data['diagnosis'].map({'B': 0, 'M': 1})

# Séparation des variables explicatives (X) et de la variable cible (y) pour le cancer
X_cancer = cancer_data.drop(columns=['diagnosis'])  # 'diagnosis' est la variable cible
y_cancer = cancer_data['diagnosis']

# Standardisation des données explicatives
scaler_cancer = StandardScaler()
X_cancer_scaled = scaler_cancer.fit_transform(X_cancer)

# %%
# Séparation en échantillons d'apprentissage et de test pour le cancer
X_cancer_train, X_cancer_test, y_cancer_train, y_cancer_test = train_test_split(X_cancer_scaled, y_cancer, test_size=0.2, random_state=42)

print(f"Shape of X_cancer_train: {X_cancer_train.shape}")
print(f"Shape of X_cancer_test: {X_cancer_test.shape}")
# Out:
# Shape of X_cancer_train: (455, 30)
# Shape of X_cancer_test: (114, 30)

# %%
# Importation des bibliothèques nécessaires
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import classification_report, confusion_matrix

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout

# Modèle pour Breast Cancer Wisconsin
model_cancer = Sequential()
model_cancer.add(Input(shape=(30,)))  # 30 entrées pour Cancer
model_cancer.add(Dense(32, activation='relu'))  # Augmentation des neurones
model_cancer.add(Dropout(0.5))  # Ajout de Dropout
model_cancer.add(Dense(16, activation='relu'))  # Augmentation des neurones
model_cancer.add(Dense(1, activation='sigmoid'))  # Sortie binaire


# Compilation du modèle
model_cancer.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Entraînement du modèle Breast Cancer Wisconsin
history_cancer = model_cancer.fit(X_cancer_train, y_cancer_train, 
                                   epochs=100, 
                                   batch_size=10, 
                                   validation_data=(X_cancer_test, y_cancer_test),
                                   verbose=1)
# Out:
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6695 - loss: 0.6307 - val_accuracy: 0.9298 - val_loss: 0.2977
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8337 - loss: 0.3754 - val_accuracy: 0.9649 - val_loss: 0.1733
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8924 - loss: 0.2602 - val_accuracy: 0.9649 - val_loss: 0.1205
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9280 - loss: 0.2035 - val_accuracy: 0.9737 - val_loss: 0.0971
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9371 - loss: 0.1717 - val_accuracy: 0.9737 - val_loss: 0.0821
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9502 - loss: 0.1485 - val_accuracy: 0.9737 - val_loss: 0.0758
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9513 - loss: 0.1375 - val_accuracy: 0.9737 - val_loss: 0.0690
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9715 - loss: 0.1039 - val_accuracy: 0.9825 - val_loss: 0.0649
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9666 - loss: 0.1144 - val_accuracy: 0.9825 - val_loss: 0.0626
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9660 - loss: 0.1187 - val_accuracy: 0.9649 - val_loss: 0.0647
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.0908 - val_accuracy: 0.9649 - val_loss: 0.0645
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9689 - loss: 0.1064 - val_accuracy: 0.9825 - val_loss: 0.0598
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9781 - loss: 0.1049 - val_accuracy: 0.9825 - val_loss: 0.0585
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9753 - loss: 0.0913 - val_accuracy: 0.9912 - val_loss: 0.0569
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9728 - loss: 0.0861 - val_accuracy: 0.9737 - val_loss: 0.0601
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9715 - loss: 0.0751 - val_accuracy: 0.9649 - val_loss: 0.0645
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9803 - loss: 0.0827 - val_accuracy: 0.9825 - val_loss: 0.0625
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9820 - loss: 0.0713 - val_accuracy: 0.9649 - val_loss: 0.0673
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9813 - loss: 0.0587 - val_accuracy: 0.9737 - val_loss: 0.0634
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9795 - loss: 0.0548 - val_accuracy: 0.9649 - val_loss: 0.0624
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9868 - loss: 0.0536 - val_accuracy: 0.9649 - val_loss: 0.0641
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.
100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9892 - loss: 0.0354 - val_accuracy: 0.9825 - val_loss: 0.0957
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9931 - loss: 0.0195 - val_accuracy: 0.9825 - val_loss: 0.0921
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9967 - loss: 0.0113 - val_accuracy: 0.9825 - val_loss: 0.0934
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9908 - loss: 0.0224 - val_accuracy: 0.9825 - val_loss: 0.0937
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9921 - loss: 0.0290 - val_accuracy: 0.9825 - val_loss: 0.0958
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9953 - loss: 0.0115 - val_accuracy: 0.9825 - val_loss: 0.0946
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9941 - loss: 0.0185 - val_accuracy: 0.9737 - val_loss: 0.0992
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9959 - loss: 0.0125 - val_accuracy: 0.9825 - val_loss: 0.0958
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9956 - loss: 0.0173 - val_accuracy: 0.9737 - val_loss: 0.1072
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9938 - loss: 0.0180 - val_accuracy: 0.9737 - val_loss: 0.1125
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9872 - loss: 0.0355 - val_accuracy: 0.9737 - val_loss: 0.1089
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9944 - loss: 0.0247 - val_accuracy: 0.9737 - val_loss: 0.1081
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.0183 - val_accuracy: 0.9737 - val_loss: 0.1051
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0101 - val_accuracy: 0.9737 - val_loss: 0.1086
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9956 - loss: 0.0164 - val_accuracy: 0.9649 - val_loss: 0.1396
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0113 - val_accuracy: 0.9649 - val_loss: 0.1381
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.0318 - val_accuracy: 0.9737 - val_loss: 0.1243
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9936 - loss: 0.0243 - val_accuracy: 0.9737 - val_loss: 0.1144

# %%
# Évaluation du modèle Breast Cancer Wisconsin
cancer_loss, cancer_accuracy = model_cancer.evaluate(X_cancer_test, y_cancer_test)
print(f"Breast Cancer Wisconsin - Loss: {cancer_loss}, Accuracy: {cancer_accuracy}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9645 - loss: 0.1380
# Breast Cancer Wisconsin - Loss: 0.11439865827560425, Accuracy: 0.9736841917037964

# %%
from sklearn.metrics import confusion_matrix, classification_report
# Prédictions pour Breast Cancer Wisconsin
y_cancer_pred = (model_cancer.predict(X_cancer_test) > 0.5).astype("int32")
print("\nBreast Cancer Wisconsin Classification Report:")
print(classification_report(y_cancer_test, y_cancer_pred))
print("Confusion Matrix:\n", confusion_matrix(y_cancer_test, y_cancer_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Breast Cancer Wisconsin Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion Matrix:
#  [[69  2]
#  [ 1 42]]

# %%
# Enregistrer le modèle au format HDF5
model_cancer.save('model_breast_cancer.h5')

print("Le modèle a été enregistré avec succès au format HDF5.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Le modèle a été enregistré avec succès au format HDF5.
